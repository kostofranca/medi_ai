# %%
import pandas as pd

# %%
df = pd.read_excel("data_28.08.2023.xlsx")

# %%
df.head()
# Out:
#    HASTA_NO  Cinsiyet  Yaş   BMI  ASA skoru (1-2-3-4)  Sigara kullanımı  \
# 0         1         0   72  26.0                    3                 1
# 1         2         0   71  25.0                    3                 1
# 2         3         0   71  33.0                    3                 0
# 3         4         0   72  34.0                    3                 0
# 4         5         0   79  28.0                    3                 0
#
#    Sigara devamı Ek hastalık  Antiagregan   NEU  ...  Patoloji  Kas var mı  \
# 0              0           1            1  8.46  ...         0           1
# 1              0           1            1  8.35  ...         0           1
# 2              0           0            0  5.14  ...         1           1
# 3              0           0            0  5.24  ...         1           1
# 4              0           1            1  4.42  ...         0           0
#
#    Nüks   Nüks zamanı (Ay)  Nüks tm sayı  Nüks tm yerleşimi  mesane boynu  \
# ...

# %%
df.describe()
# Out:
#         HASTA_NO    Cinsiyet         Yaş         BMI  ASA skoru (1-2-3-4)  \
# count  143.00000  143.000000  143.000000  143.000000           143.000000
# mean    72.00000    0.153846   63.160839   26.674126             2.531469
# std     41.42463    0.362069   10.266622    3.525396             0.500763
# min      1.00000    0.000000   37.000000   18.800000             2.000000
# 25%     36.50000    0.000000   55.000000   24.550000             2.000000
# 50%     72.00000    0.000000   64.000000   26.200000             3.000000
# 75%    107.50000    0.000000   71.000000   28.765000             3.000000
# max    143.00000    1.000000   83.000000   36.000000             3.000000
#
#        Sigara kullanımı  Sigara devamı  Antiagregan         NEU        LYMP  \
# count        143.000000     143.000000   143.000000  143.000000  143.000000
# mean           0.748252       0.272727     0.412587    5.189301    2.607552
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   HASTA_NO               143 non-null    int64
#  1   Cinsiyet               143 non-null    int64
#  2   Yaş                    143 non-null    int64
#  3   BMI                    143 non-null    float64
#  4   ASA skoru (1-2-3-4)    143 non-null    int64
#  5   Sigara kullanımı       143 non-null    int64
#  6   Sigara devamı          143 non-null    int64
#  7   Ek hastalık            143 non-null    object
#  8   Antiagregan            143 non-null    int64
#  9   NEU                    143 non-null    float64
#  10  LYMP                   143 non-null    float64
#  11  NLR                    143 non-null    float64
#  12  Başvuru                143 non-null    int64
#  13  TİT                    143 non-null    int64
# ...

# %%
# Out:
# 32
